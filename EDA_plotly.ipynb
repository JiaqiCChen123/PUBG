# %%
import numpy as np
import plotly.graph_objects as go
import os
import ast

os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages "org.apache.hadoop:hadoop-aws:2.7.4" pyspark-shell'
sc = SparkContext.getOrCreate()
sc._jsc.hadoopConfiguration().set("fs.s3.impl",
                                  "org.apache.hadoop.fs.s3a.S3AFileSystem")
sc._jsc.hadoopConfiguration().set('fs.s3a.access.key', 'AKIAZ2EY7HOF22LWMBLA')
sc._jsc.hadoopConfiguration().set(
    'fs.s3a.secret.key', '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')
rdd = sc.textFile("s3a://chickenspark/deaths/weapon")
weapon_kill = rdd.collect()
weapon = [eval(x) for x in weapon_kill]
rdd1 = sc.textFile("s3a://chickenspark/deaths/no_weapon")
no_weapon_kill = rdd1.collect()
no_weapon = [eval(x) for x in no_weapon_kill]
no_weapon_method = [x[0] for x in no_weapon]
no_weapon_number = [x[1] for x in no_weapon]
fig = go.Figure([go.Bar(x=no_weapon_method, y=no_weapon_number)])
fig.update_layout(title={
    'text': "Number of Kills by Special Methods",
    'y': 0.9,
    'x': 0.5,
    'xanchor': 'center',
    'yanchor': 'top'}, xaxis_title="Number of Kills", yaxis_title="Weapons")
fig.show()
weapon_method = [x[0] for x in weapon]
weapon_number = [x[1] for x in weapon]
fig = go.Figure([go.Bar(x=weapon_number, y=weapon_method, orientation='h')])

fig.update_layout(title={
    'text': "Number of Kills by Different Weapons",
    'y': 0.9,
    'x': 0.5,
    'xanchor': 'center',
    'yanchor': 'top'}, yaxis={'categoryorder': 'total ascending'}, xaxis_title="Number of Kills", yaxis_title="Weapons")
fig.update_layout({'plot_bgcolor': 'rgba(0, 0, 0, 0)'})

fig.show()
rdd2 = sc.textFile(
    "s3a://chickenspark/aggregate/temp/Kill_Damage_value_histogram_for_long_surviver")
rdd3 = sc.textFile("s3a://chickenspark/aggregate/temp/assistance_histogram")
rdd4 = sc.textFile("s3a://chickenspark/aggregate/temp/damage_histogram")
rdd5 = sc.textFile(
    "s3a://chickenspark/aggregate/temp/damage_histogram_for_long_surviver")
rdd6 = sc.textFile("s3a://chickenspark/aggregate/temp/kill_histogram")
rdd7 = sc.textFile(
    "s3a://chickenspark/aggregate/temp/kill_histogram_for_long_surviver")
rdd8 = sc.textFile("s3a://chickenspark/aggregate/temp/survive_histogram")
rdd9 = sc.textFile("s3a://chickenspark/deaths/death_map_live_final_1200")
rdd10 = sc.textFile("s3a://chickenspark/deaths/death_map_live_final_180")
rdd11 = sc.textFile("s3a://chickenspark/deaths/death_map_live_final_180_600")
rdd12 = sc.textFile("s3a://chickenspark/deaths/death_map_live_final_600_1200")
larger1200 = rdd9.collect()
less180 = rdd10.collect()
between180 = rdd11.collect()
between600 = rdd12.collect()
rdd3 = rdd3.map(lambda x: eval(x))
rdd3 = rdd3.map(lambda x: ast.literal_eval(x))
damage = rdd5.map(lambda x: eval(x)).filter(
    lambda x: x != 0).filter(lambda x: x <= 1000).collect()
damage0 = rdd5.map(lambda x: eval(x)).filter(lambda x: x == 0).count()
damage0
fig = go.Figure(data=[go.Histogram(x=damage)])
fig.update_layout(title={
    'text': "Damage Distributions",
    'y': 0.9,
    'x': 0.5,
    'xanchor': 'center',
    'yanchor': 'top'}, xaxis_title="Damage")
fig.show()
kill = rdd7.map(lambda x: eval(x)).filter(lambda x: x <= 20).collect()
kill0 = rdd7.map(lambda x: eval(x)).filter(lambda x: x == 0).count()
fig = go.Figure(data=[go.Histogram(x=kill)])
fig.update_layout(title={
    'text': "Kill Distributions",
    'y': 0.9,
    'x': 0.5,
    'xanchor': 'center',
    'yanchor': 'top'}, xaxis_title="Kill")
fig.show()
ride = sc.textFile('s3a://chickenspark/aggregate/ride')
ride = ride.map(lambda x: eval(x)).map(lambda x: eval(x[1]))
ride1 = ride.filter(lambda x: x <= 500).count()
ride2 = ride.filter(lambda x: x > 500 and x <= 1000).count()
ride3 = ride.filter(lambda x: x > 1000 and x <= 1500).count()
ride4 = ride.filter(lambda x: x > 1500 and x <= 2000).count()
ride5 = ride.filter(lambda x: x > 2000 and x <= 2500).count()
ride6 = ride.filter(lambda x: x > 2500 and x <= 3000).count()
ride7 = ride.filter(lambda x: x > 3000 and x <= 3500).count()
ride8 = ride.filter(lambda x: x > 3500 and x <= 4000).count()
ride9 = ride.filter(lambda x: x > 4000 and x <= 4500).count()
ride10 = ride.filter(lambda x: x > 4500 and x <= 5000).count()
ride_distance = ['<500', '500~1000', '1000~1500', '1500~2000', '2000~2500',
                 '2500~3000', '3000~3500', '3500~4000', '4000~4500', '4500~5000']
ride_number = [ride1, ride2, ride3, ride4,
               ride5, ride6, ride7, ride8, ride9, ride10]
fig = go.Figure([go.Bar(x=ride_distance, y=ride_number)])
fig.update_layout(title={
    'text': "Ride Distance of Long Survivors",
    'y': 0.9,
    'x': 0.5,
    'xanchor': 'center',
    'yanchor': 'top'}, xaxis_title="Distance", yaxis_title="Number of people")
fig.show()
walk = sc.textFile('s3a://chickenspark/aggregate/walk')
walk = walk.map(lambda x: eval(x)).map(lambda x: eval(x[1]))
walklist = walk.collect()
walk1 = walk.filter(lambda x: x <= 500).count()
walk2 = walk.filter(lambda x: x > 500 and x <= 1000).count()
walk3 = walk.filter(lambda x: x > 1000 and x <= 1500).count()
walk4 = walk.filter(lambda x: x > 1500 and x <= 2000).count()
walk5 = walk.filter(lambda x: x > 2000 and x <= 2500).count()
walk6 = walk.filter(lambda x: x > 2500 and x <= 3000).count()
walk7 = walk.filter(lambda x: x > 3000 and x <= 3500).count()
walk8 = walk.filter(lambda x: x > 3500 and x <= 4000).count()
walk9 = walk.filter(lambda x: x > 4000 and x <= 4500).count()
walk10 = walk.filter(lambda x: x > 4500 and x <= 5000).count()
walk_distance = ['<500', '500~1000', '1000~1500', '1500~2000', '2000~2500',
                 '2500~3000', '3000~3500', '3500~4000', '4000~4500', '4500~5000']
walk_number = [walk1, walk2, walk3, walk4,
               walk5, walk6, walk7, walk8, walk9, walk10]
fig = go.Figure([go.Bar(x=walk_distance, y=walk_number)])
fig.update_layout(title={
    'text': "walk Distance of Long Survivors",
    'y': 0.9,
    'x': 0.5,
    'xanchor': 'center',
    'yanchor': 'top'}, xaxis_title="Distance", yaxis_title="Number of people")
fig.show()
using_map = ['ERANGEL', 'MIRAMAR']
fig = go.Figure(data=[
    go.Bar(name='<180', x=using_map, y=less180[1:]),
    go.Bar(name='180~600', x=using_map, y=between180[1:]),
    go.Bar(name='600~1200', x=using_map, y=between600[1:]),
    go.Bar(name='>1200', x=using_map, y=larger1200[1:]),
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show()
rdd_assist = sc.textFile("s3a://chickenspark/aggregate/assist")
all_assist = rdd_assist.sample(False, 0.0001).collect()
fig = go.Figure(data=[go.Histogram(x=all_assist)])
fig.update_layout(title={
    'text': "Assist Distributions",
    'y': 0.9,
    'x': 0.5,
    'xanchor': 'center',
    'yanchor': 'top'}, xaxis_title="Assist")
fig.show()
rdd_dmg = sc.textFile("s3a://chickenspark/aggregate/dmg")
rdd_kills = sc.textFile("s3a://chickenspark/aggregate/kills")
all_dmg = rdd_dmg.sample(False, 0.0001).collect()
all_kills = rdd_kills.sample(False, 0.0001).collect()
fig = go.Figure(data=[go.Histogram(x=all_dmg)])
fig.update_layout(title={
    'text': "Damage Distributions",
    'y': 0.9,
    'x': 0.5,
    'xanchor': 'center',
    'yanchor': 'top'}, xaxis_title="Damage")
fig.show()
fig = go.Figure(data=[go.Histogram(x=all_kills)])
fig.update_layout(title={
    'text': "kills Distributions",
    'y': 0.9,
    'x': 0.5,
    'xanchor': 'center',
    'yanchor': 'top'}, xaxis_title="kills")
fig.show()
